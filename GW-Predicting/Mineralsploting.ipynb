# %%
import numpy as np
from operator import itemgetter
from matplotlib import pyplot as plt  
import os
import pandas as pd
import pickle
from flask_mysqldb import MySQL
import MySQLdb.cursors
import mysql.connector

# %%
# # mysql connection
# app.config['MYSQL_HOST'] = 'localhost'
# app.config['MYSQL_USER'] = 'root'
# app.config['MYSQL_PASSWORD'] = ''
# app.config['MYSQL_DB'] = 'gwdet'

# # Intialize MySQL
# mysql = MySQL(app)

# %%
mysql = mysql.connector.connect(host="localhost",
                               user="root",
                               password="",
                               database="gwdet")
cursor = mysql.cursor()

# %%
# def sum_of_list(l,n):
#     if n == 0:
#         return l[n]
#     return l[n] + sum_of_list(l,n-1)

# %%
cursor.execute('SELECT * FROM gw')
gw = cursor.fetchall()

# li=[]
# for i in range(len(gw)):
#             li.append(gw[i])
# #lt = len(li)
# print(li)
# ars = list(map(itemgetter('ARSE'),li))
# #print(ars)

# %%
ars=[]
for i in gw:
    ars.append(i[8])
#print(ars)
#lt = len(ars)
# sars=sum_of_list(ars,lt-1)
# #avars=sars/lt
# print(ars,'\n',lt,'\n',sars)

yer=[]
for i in gw:
    yer.append(i[1])
#print(yer)

plt.bar(yer, ars)
plt.ylim(0, 20)
plt.xlabel("Yer")
plt.ylabel("Arsenic")
plt.title("Arsenic Value Year wise")
plt.show()
plt.savefig('../static/PlotPic/Arsenic_Value_Year_wise.png')

# %%
mn=[]
for i in gw:
    mn.append(i[9])

yer=[]
for i in gw:
    yer.append(i[1])
    
plt.bar(yer, mn)
plt.ylim(0, 20)
plt.xlabel("Yer")
plt.ylabel("Mangnesium")
plt.title("Mangnesium Value Year wise")
plt.show()
plt.savefig('../static/PlotPic/Magnesium_Value_Year_wise.png')

# %%
fe=[]
for i in gw:
    fe.append(i[10])


yer=[]
for i in gw:
    yer.append(i[1])
    
plt.bar(yer, ars)
plt.ylim(0, 20)
plt.xlabel("Yer")
plt.ylabel("Iron")
plt.title("Iron Value Year wise")
plt.show()
plt.savefig('../static/PlotPic/Iron_Value_Year_wise.png')

# %%
ca=[]
for i in gw:
    ca.append(i[11])

    
yer=[]
for i in gw:
    yer.append(i[1])
    
plt.bar(yer, ars)
plt.ylim(0, 20)
plt.xlabel("Yer")
plt.ylabel("Calcium")
plt.title("Calcium Value Year wise")
plt.show()
plt.savefig('../static/PlotPic/Calcium_Value_Year_wise.png')
